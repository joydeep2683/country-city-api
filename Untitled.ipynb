# %%
import pandas as pd

# %%
df = pd.read_csv('files/world_cities.csv')

# %%
df.head()
# Out:
#                city               country          subcountry  geonameid
# 0      les Escaldes               Andorra  Escaldes-Engordany    3040051
# 1  Andorra la Vella               Andorra    Andorra la Vella    3041563
# 2    Umm al Qaywayn  United Arab Emirates      Umm al Qaywayn     290594
# 3    Ras al-Khaimah  United Arab Emirates     Raʼs al Khaymah     291074
# 4      Khawr Fakkān  United Arab Emirates        Ash Shāriqah     291696

# %%
df = df.applymap(lambda x: x.lower() if type(x) == str else x)

# %%
df.to_csv('files/world_cities_new.csv', index=False)

# %%
set(df['city'].values)
# Out:
# {'yangshuo',
#  'hirakata',
#  'fresnillo',
#  'paragominas',
#  'union',
#  'liquica',
#  'fort beaufort',
#  'gombe',
#  "nar'yan-mar",
#  'wa',
#  'mariāhu',
#  'enem',
#  'naranjito',
#  'janūb as surrah',
#  'stamford',
#  'quzhou',
#  'santander de quilichao',
#  'uyo',
#  'samarinda',
#  'souk ahras',
#  'lingen',
#  'ramsgate',
#  'lambaréné',
#  'shashi',
#  'muang xay',
#  'murakami',
#  'chodzież',
#  'patnos',
#  'fabriano',
#  'cheraga',
#  'manbij',
#  'guaçuí',
#  'santa cruz xoxocotlán',
#  'banyumas',
#  'chalfont saint peter',
#  'silopi',
#  'damnoen saduak',
#  'ghijduwon',
#  'bayshore gardens',
#  'abomsa',
#  'barka kāna',
#  'san josé de guanipa',
#  'perumpāvūr',
#  'durban',
#  'solan',
#  'tulungagung',
#  'tumkūr',
#  'burscheid',
#  'níkaia',
#  'naduvannūr',
#  'nailsea',
#  'monaco',
#  'chanduasi',
#  'kāmyārān',
#  'silute',
#  'harvey',
#  'kāgal',
#  'malir cantonment',
#  'coronel vivida',
#  'balqash',
#  'kaulsdorf',
#  'forssa',
#  'opelika',
# ...
